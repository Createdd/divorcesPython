# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
print('hello world')
# Out:
# hello world

# %%
data = pd.read_csv('divorce.csv', delimiter=";")
data
# Out:
#    NUTS1 NUTS2  REF_YEAR  TOTAL  HUSBAND_RESPONSIBLE  WIFE_RESPONSIBLE  \
# 0    AT3  AT32      1985    804                   90                12
# 1    AT3  AT32      1986    729                   79                 8
# 2    AT3  AT32      1987    759                   76                 9
# 3    AT3  AT32      1988    802                   56                 7
# 4    AT3  AT32      1989    800                   64                 5
# 5    AT3  AT32      1990    803                   73                 6
# 6    AT3  AT32      1991    849                   35                 5
# 7    AT3  AT32      1992    864                   53                 8
# 8    AT3  AT32      1993    821                   44                 6
# 9    AT3  AT32      1994    882                   55                 6
# 10   AT3  AT32      1995    979                   78                 8
# 11   AT3  AT32      1996   1011                   76                 8
# ...

# %%
year = data.REF_YEAR
total = data.TOTAL
husband = data.HUSBAND_RESPONSIBLE
wife = data.WIFE_RESPONSIBLE
both = data.BOTH_RESPONSIBLE
neither = data.NEITHER_RESPONSIBLE
plt.title("Responsibilities of divorces over the years")
plt.plot(year, total)
plt.plot(year, husband)
plt.plot(year, wife)
plt.plot(year, both)
plt.plot(year, neither)
plt.legend(['total', 'only husband', 'only wife', 'both', 'neither'])
plt.show()

# %%
data1985 = data[data.REF_YEAR == 1985]
data2014 = data[data.REF_YEAR == 2014]

resBoth = data[data.BOTH_RESPONSIBLE]
resNeither = data.NEITHER_RESPONSIBLE

resBoth


# plt.hist(resBoth)
#plt.subplot(2,1,1)
#plt.hist(resNeither)
#plt.subplot(2,1,2)
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-232bc82e592e> in <module>()
#       2 data2014 = data[data.REF_YEAR == 2014]
#       3
# ----> 4 resBoth = data[data.BOTH_RESPONSIBLE]
#       5 resNeither = data.NEITHER_RESPONSIBLE
#       6
#
# /Users/DanielDeutsch/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2054         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2055             # either boolean or fancy integer index
# -> 2056             return self._getitem_array(key)
#    2057         elif isinstance(key, DataFrame):
#    2058             return self._getitem_frame(key)
#
# /Users/DanielDeutsch/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2098             return self.take(indexer, axis=0, convert=False)
#    2099         else:
# ...
